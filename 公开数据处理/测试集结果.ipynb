# %%
import warnings
import configparser
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ------------------------------------------设置参数-----------------------------------------------------

# 可视化SC效果
data1 = pd.read_csv(r'D:\python_common\代码_感知质量大论文\公开数据处理\cp_感知质量数据集\skep_ernie_1.0_large_ch\_Normal_Lstm_Res_max_8_cross_entropy\confusion_matrix.csv')
fig, ax = plt.subplots()
ax.xaxis.tick_top()
# 不显示右侧的刻度表


sns.heatmap(data1, cmap='gray', annot=True, linewidths=0.5, fmt='g', annot_kws={'size': 20, 'weight': 'bold', 'family': 'Times New Roman'},
            cbar=False)
# plt.title('情感分类混淆矩阵',fontfamily='STsong',size=20,weight='bold',pad=10,loc='center',color='black')
plt.xticks([0.5,1.5,2.5],['消极','中性','积极'],fontfamily='stsong',size=20)
plt.yticks([0.5,1.5,2.5],['消极','中性','积极'],fontfamily='stsong',size=20,rotation=0)
plt.tight_layout()
plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\python_base\38\lib\site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=1.2 in d:\python_base\38\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\python_base\38\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python_base\38\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\python_base\38\lib\site-packages (from pandas>=1.2->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in d:\python_base\38\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    --------------------------------------- 294.9/294.9 kB 45.7 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
